# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import mglearn

from IPython.display import display

# %matplotlib inline

# %%
data = pd.read_csv('sc2-matches-history.csv')

# %%
pd.options.display.max_rows = 20

# %%
data
# Out:
#         match_date player_1 player_1_match_status score     player_2  \
# 0       09/19/2016       MC               [loser]   0–2        Stats
# 1       09/19/2016       MC              [winner]   2–1      NaTuRal
# 2       09/19/2016       MC               [loser]   1–2         Dark
# 3       09/13/2016       MC               [loser]   0–2   INnoVation
# 4       08/27/2016       MC               [loser]   0–1         TRUE
# 5       07/17/2016       MC               [loser]   0–1         Cure
# 6       07/16/2016       MC              [winner]   1–0        Super
# 7       07/16/2016       MC              [winner]   1–0        aLive
# 8       07/16/2016       MC              [winner]   1–0      Curious
# 9       07/06/2016       MC               [loser]   0–2         Zest
# ...            ...      ...                   ...   ...          ...
# 374784  02/28/2013    Sabre               [loser]   2–3        Simba
# 374785  02/21/2013    Sabre               [loser]   0–1       Grubby
# 374786  08/27/2012    Sabre               [loser]   1–2        JakeP
# 374787  08/27/2012    Sabre               [loser]   0–2   JonnyREcco
# 374788  07/06/2012    Sabre               [loser]   0–3     Shibbxyz
# 374789  07/06/2012    Sabre               [loser]   0–2          Dez
# 374790  07/06/2012    Sabre              [winner]   2–1  Stolensheep
# 374791  06/07/2012    Sabre               [loser]   0–2       Jimmeh
# 374792  06/07/2012    Sabre              [winner]   2–0       Niacim
# 374793  10/26/2011    Sabre               [loser]   0–2      Pjonkan
#
#        player_2_match_status player_1_race player_2_race addon tournament_type
# 0                   [winner]             P             P  LotV          online
# 1                    [loser]             P             T  LotV          online
# 2                   [winner]             P             Z  LotV          online
# 3                   [winner]             P             T  LotV          online
# 4                   [winner]             P             Z  LotV          online
# 5                   [winner]             P             T  LotV         offline
# 6                    [loser]             P             P  LotV         offline
# 7                    [loser]             P             T  LotV         offline
# 8                    [loser]             P             Z  LotV         offline
# 9                   [winner]             P             P  LotV         offline
# ...                      ...           ...           ...   ...             ...
# 374784              [winner]             Z             T  HotS          online
# 374785              [winner]             Z             P  HotS          online
# 374786              [winner]             Z             P   WoL         offline
# 374787              [winner]             Z             Z   WoL         offline
# 374788              [winner]             Z             Z   WoL          online
# 374789              [winner]             Z             P   WoL          online
# 374790               [loser]             Z             Z   WoL          online
# 374791              [winner]             Z             T   WoL          online
# 374792               [loser]             Z             P   WoL          online
# 374793              [winner]             T             P   WoL          online
#
# [374794 rows x 10 columns]

# %%
sns.countplot('player_1_race', hue='player_1_match_status', data=data);

# %%
sns.countplot('player_1_race', hue='player_2_match_status', data=data);

# %%
data.groupby('player_1_race').count()
# Out:
#                match_date  player_1  player_1_match_status   score  player_2  \
# player_1_race
# P                  120455    120455                 120455  120455    120455
# R                     798       798                    798     798       798
# T                  107193    107193                 107193  107193    107192
# Z                  146348    146348                 146348  146348    146348
#
#                player_2_match_status  player_2_race   addon  tournament_type
# player_1_race
# P                             120455         120455  120455           120455
# R                                798            798     798              798
# T                             107193         107193  107193           107193
# Z                             146348         146348  146348           146348

# %%
data.describe()
# Out:
#         match_date player_1 player_1_match_status   score player_2  \
# count       374794   374794                374794  374794   374793
# unique        2733     1856                     2      93    10801
# top     04/11/2015      Bly              [winner]     2–0      Bly
# freq           783     3932                206918   93890     3494
#
#        player_2_match_status player_1_race player_2_race   addon  \
# count                 374794        374794        374794  374794
# unique                     2             4             4       3
# top                  [loser]             Z             Z    HotS
# freq                  205898        146348        143034  152754
#
#        tournament_type
# count           374794
# unique               2
# top             online
# freq            297507

# %%
data
# Out:
#         match_date player_1 player_1_match_status score     player_2  \
# 0       09/19/2016       MC               [loser]   0–2        Stats
# 1       09/19/2016       MC              [winner]   2–1      NaTuRal
# 2       09/19/2016       MC               [loser]   1–2         Dark
# 3       09/13/2016       MC               [loser]   0–2   INnoVation
# 4       08/27/2016       MC               [loser]   0–1         TRUE
# 5       07/17/2016       MC               [loser]   0–1         Cure
# 6       07/16/2016       MC              [winner]   1–0        Super
# 7       07/16/2016       MC              [winner]   1–0        aLive
# 8       07/16/2016       MC              [winner]   1–0      Curious
# 9       07/06/2016       MC               [loser]   0–2         Zest
# ...            ...      ...                   ...   ...          ...
# 374784  02/28/2013    Sabre               [loser]   2–3        Simba
# 374785  02/21/2013    Sabre               [loser]   0–1       Grubby
# 374786  08/27/2012    Sabre               [loser]   1–2        JakeP
# 374787  08/27/2012    Sabre               [loser]   0–2   JonnyREcco
# 374788  07/06/2012    Sabre               [loser]   0–3     Shibbxyz
# 374789  07/06/2012    Sabre               [loser]   0–2          Dez
# 374790  07/06/2012    Sabre              [winner]   2–1  Stolensheep
# 374791  06/07/2012    Sabre               [loser]   0–2       Jimmeh
# 374792  06/07/2012    Sabre              [winner]   2–0       Niacim
# 374793  10/26/2011    Sabre               [loser]   0–2      Pjonkan
#
#        player_2_match_status player_1_race player_2_race addon tournament_type
# 0                   [winner]             P             P  LotV          online
# 1                    [loser]             P             T  LotV          online
# 2                   [winner]             P             Z  LotV          online
# 3                   [winner]             P             T  LotV          online
# 4                   [winner]             P             Z  LotV          online
# 5                   [winner]             P             T  LotV         offline
# 6                    [loser]             P             P  LotV         offline
# 7                    [loser]             P             T  LotV         offline
# 8                    [loser]             P             Z  LotV         offline
# 9                   [winner]             P             P  LotV         offline
# ...                      ...           ...           ...   ...             ...
# 374784              [winner]             Z             T  HotS          online
# 374785              [winner]             Z             P  HotS          online
# 374786              [winner]             Z             P   WoL         offline
# 374787              [winner]             Z             Z   WoL         offline
# 374788              [winner]             Z             Z   WoL          online
# 374789              [winner]             Z             P   WoL          online
# 374790               [loser]             Z             Z   WoL          online
# 374791              [winner]             Z             T   WoL          online
# 374792               [loser]             Z             P   WoL          online
# 374793              [winner]             T             P   WoL          online
#
# [374794 rows x 10 columns]

# %%
data['year'] = pd.DatetimeIndex(data['match_date']).year

# %%
data
# Out:
#         match_date player_1 player_1_match_status score     player_2  \
# 0       09/19/2016       MC               [loser]   0–2        Stats
# 1       09/19/2016       MC              [winner]   2–1      NaTuRal
# 2       09/19/2016       MC               [loser]   1–2         Dark
# 3       09/13/2016       MC               [loser]   0–2   INnoVation
# 4       08/27/2016       MC               [loser]   0–1         TRUE
# 5       07/17/2016       MC               [loser]   0–1         Cure
# 6       07/16/2016       MC              [winner]   1–0        Super
# 7       07/16/2016       MC              [winner]   1–0        aLive
# 8       07/16/2016       MC              [winner]   1–0      Curious
# 9       07/06/2016       MC               [loser]   0–2         Zest
# ...            ...      ...                   ...   ...          ...
# 374784  02/28/2013    Sabre               [loser]   2–3        Simba
# 374785  02/21/2013    Sabre               [loser]   0–1       Grubby
# 374786  08/27/2012    Sabre               [loser]   1–2        JakeP
# 374787  08/27/2012    Sabre               [loser]   0–2   JonnyREcco
# 374788  07/06/2012    Sabre               [loser]   0–3     Shibbxyz
# 374789  07/06/2012    Sabre               [loser]   0–2          Dez
# 374790  07/06/2012    Sabre              [winner]   2–1  Stolensheep
# 374791  06/07/2012    Sabre               [loser]   0–2       Jimmeh
# 374792  06/07/2012    Sabre              [winner]   2–0       Niacim
# 374793  10/26/2011    Sabre               [loser]   0–2      Pjonkan
#
#        player_2_match_status player_1_race player_2_race addon  \
# 0                   [winner]             P             P  LotV
# 1                    [loser]             P             T  LotV
# 2                   [winner]             P             Z  LotV
# 3                   [winner]             P             T  LotV
# 4                   [winner]             P             Z  LotV
# 5                   [winner]             P             T  LotV
# 6                    [loser]             P             P  LotV
# 7                    [loser]             P             T  LotV
# 8                    [loser]             P             Z  LotV
# 9                   [winner]             P             P  LotV
# ...                      ...           ...           ...   ...
# 374784              [winner]             Z             T  HotS
# 374785              [winner]             Z             P  HotS
# 374786              [winner]             Z             P   WoL
# 374787              [winner]             Z             Z   WoL
# 374788              [winner]             Z             Z   WoL
# 374789              [winner]             Z             P   WoL
# 374790               [loser]             Z             Z   WoL
# 374791              [winner]             Z             T   WoL
# 374792               [loser]             Z             P   WoL
# 374793              [winner]             T             P   WoL
#
#        tournament_type  year
# 0               online  2016
# 1               online  2016
# 2               online  2016
# 3               online  2016
# 4               online  2016
# 5              offline  2016
# 6              offline  2016
# 7              offline  2016
# 8              offline  2016
# 9              offline  2016
# ...                ...   ...
# 374784          online  2013
# 374785          online  2013
# 374786         offline  2012
# 374787         offline  2012
# 374788          online  2012
# 374789          online  2012
# 374790          online  2012
# 374791          online  2012
# 374792          online  2012
# 374793          online  2011
#
# [374794 rows x 11 columns]

# %%
sns.countplot('year', hue='tournament_type', data=data);

# %%
 sns.countplot('year', hue='addon', data=data);

# %%
data.loc[data.addon == 'WoL']
# Out:
#         match_date   player_1 player_1_match_status score     player_2  \
# 412     02/22/2013         MC               [loser]   2–3         RorO
# 415     02/14/2013         MC              [winner]   2–0       GuMiho
# 416     02/14/2013         MC              [winner]   2–0       Losira
# 417     02/14/2013         MC               [loser]   0–2      Curious
# 418     02/06/2013         MC               [loser]   1–2    Hurricane
# 419     02/06/2013         MC              [winner]   2–1       Mamuri
# 420     01/30/2013         MC               [loser]   0–2         Seed
# 421     01/30/2013         MC              [winner]   2–0          Krr
# 422     01/30/2013         MC              [winner]   2–1        Lucky
# 423     01/30/2013         MC              [winner]   2–0        White
# ...            ...        ...                   ...   ...          ...
# 374722  04/22/2011  Wochtulka               [loser]   1–2      Byakuya
# 374723  04/22/2011  Wochtulka              [winner]   2–1       Thebis
# 374786  08/27/2012      Sabre               [loser]   1–2        JakeP
# 374787  08/27/2012      Sabre               [loser]   0–2   JonnyREcco
# 374788  07/06/2012      Sabre               [loser]   0–3     Shibbxyz
# 374789  07/06/2012      Sabre               [loser]   0–2          Dez
# 374790  07/06/2012      Sabre              [winner]   2–1  Stolensheep
# 374791  06/07/2012      Sabre               [loser]   0–2       Jimmeh
# 374792  06/07/2012      Sabre              [winner]   2–0       Niacim
# 374793  10/26/2011      Sabre               [loser]   0–2      Pjonkan
#
#        player_2_match_status player_1_race player_2_race addon  \
# 412                 [winner]             P             Z   WoL
# 415                  [loser]             P             T   WoL
# 416                  [loser]             P             Z   WoL
# 417                 [winner]             P             Z   WoL
# 418                 [winner]             P             P   WoL
# 419                  [loser]             P             Z   WoL
# 420                 [winner]             P             P   WoL
# 421                  [loser]             P             P   WoL
# 422                  [loser]             P             Z   WoL
# 423                  [loser]             P             Z   WoL
# ...                      ...           ...           ...   ...
# 374722              [winner]             P             P   WoL
# 374723               [loser]             P             P   WoL
# 374786              [winner]             Z             P   WoL
# 374787              [winner]             Z             Z   WoL
# 374788              [winner]             Z             Z   WoL
# 374789              [winner]             Z             P   WoL
# 374790               [loser]             Z             Z   WoL
# 374791              [winner]             Z             T   WoL
# 374792               [loser]             Z             P   WoL
# 374793              [winner]             T             P   WoL
#
#        tournament_type  year
# 412            offline  2013
# 415            offline  2013
# 416            offline  2013
# 417            offline  2013
# 418             online  2013
# 419             online  2013
# 420             online  2013
# 421             online  2013
# 422             online  2013
# 423             online  2013
# ...                ...   ...
# 374722         offline  2011
# 374723         offline  2011
# 374786         offline  2012
# 374787         offline  2012
# 374788          online  2012
# 374789          online  2012
# 374790          online  2012
# 374791          online  2012
# 374792          online  2012
# 374793          online  2011
#
# [111582 rows x 11 columns]

# %%
sns.countplot('addon', hue='player_1_race', data=data.loc[data.player_1_match_status == '[winner]'])

# %%
ax=sns.countplot('addon', hue='player_2_race', data=data.loc[data.player_2_match_status == '[winner]'])

# %%
data.loc[data.player_1_match_status == '[winner]','player_1_match_status_int'] = 1
data.loc[data.player_1_match_status == '[loser]','player_1_match_status_int'] = 0

data.loc[data.player_1_race == 'P','player_1_race_int'] = 0
data.loc[data.player_1_race == 'T','player_1_race_int'] = 1
data.loc[data.player_1_race == 'Z','player_1_race_int'] = 2

data.loc[data.addon == 'LotV','addon_int'] = 0
data.loc[data.addon == 'HotS','addon_int'] = 1
data.loc[data.addon == 'WoL','addon_int'] = 2

data['matchup'] = data.player_1_race + ' ' + data.player_2_race

# data.loc(data['player_1_match_status'] == '[loser]', player_1_match_status_int) = 0
# sns.factorplot('addon', 'player_1_race', hue='player_1_match_status', data=data);

# %%
data
# Out:
#         match_date player_1 player_1_match_status score     player_2  \
# 0       09/19/2016       MC               [loser]   0–2        Stats
# 1       09/19/2016       MC              [winner]   2–1      NaTuRal
# 2       09/19/2016       MC               [loser]   1–2         Dark
# 3       09/13/2016       MC               [loser]   0–2   INnoVation
# 4       08/27/2016       MC               [loser]   0–1         TRUE
# 5       07/17/2016       MC               [loser]   0–1         Cure
# 6       07/16/2016       MC              [winner]   1–0        Super
# 7       07/16/2016       MC              [winner]   1–0        aLive
# 8       07/16/2016       MC              [winner]   1–0      Curious
# 9       07/06/2016       MC               [loser]   0–2         Zest
# ...            ...      ...                   ...   ...          ...
# 374784  02/28/2013    Sabre               [loser]   2–3        Simba
# 374785  02/21/2013    Sabre               [loser]   0–1       Grubby
# 374786  08/27/2012    Sabre               [loser]   1–2        JakeP
# 374787  08/27/2012    Sabre               [loser]   0–2   JonnyREcco
# 374788  07/06/2012    Sabre               [loser]   0–3     Shibbxyz
# 374789  07/06/2012    Sabre               [loser]   0–2          Dez
# 374790  07/06/2012    Sabre              [winner]   2–1  Stolensheep
# 374791  06/07/2012    Sabre               [loser]   0–2       Jimmeh
# 374792  06/07/2012    Sabre              [winner]   2–0       Niacim
# 374793  10/26/2011    Sabre               [loser]   0–2      Pjonkan
#
#        player_2_match_status player_1_race player_2_race addon  \
# 0                   [winner]             P             P  LotV
# 1                    [loser]             P             T  LotV
# 2                   [winner]             P             Z  LotV
# 3                   [winner]             P             T  LotV
# 4                   [winner]             P             Z  LotV
# 5                   [winner]             P             T  LotV
# 6                    [loser]             P             P  LotV
# 7                    [loser]             P             T  LotV
# 8                    [loser]             P             Z  LotV
# 9                   [winner]             P             P  LotV
# ...                      ...           ...           ...   ...
# 374784              [winner]             Z             T  HotS
# 374785              [winner]             Z             P  HotS
# 374786              [winner]             Z             P   WoL
# 374787              [winner]             Z             Z   WoL
# 374788              [winner]             Z             Z   WoL
# 374789              [winner]             Z             P   WoL
# 374790               [loser]             Z             Z   WoL
# 374791              [winner]             Z             T   WoL
# 374792               [loser]             Z             P   WoL
# 374793              [winner]             T             P   WoL
#
#        tournament_type  year  player_1_match_status_int  player_1_race_int  \
# 0               online  2016                        0.0                0.0
# 1               online  2016                        1.0                0.0
# 2               online  2016                        0.0                0.0
# 3               online  2016                        0.0                0.0
# 4               online  2016                        0.0                0.0
# 5              offline  2016                        0.0                0.0
# 6              offline  2016                        1.0                0.0
# 7              offline  2016                        1.0                0.0
# 8              offline  2016                        1.0                0.0
# 9              offline  2016                        0.0                0.0
# ...                ...   ...                        ...                ...
# 374784          online  2013                        0.0                2.0
# 374785          online  2013                        0.0                2.0
# 374786         offline  2012                        0.0                2.0
# 374787         offline  2012                        0.0                2.0
# 374788          online  2012                        0.0                2.0
# 374789          online  2012                        0.0                2.0
# 374790          online  2012                        1.0                2.0
# 374791          online  2012                        0.0                2.0
# 374792          online  2012                        1.0                2.0
# 374793          online  2011                        0.0                1.0
#
#         addon_int matchup
# 0             0.0     P P
# 1             0.0     P T
# 2             0.0     P Z
# 3             0.0     P T
# 4             0.0     P Z
# 5             0.0     P T
# 6             0.0     P P
# 7             0.0     P T
# 8             0.0     P Z
# 9             0.0     P P
# ...           ...     ...
# 374784        1.0     Z T
# 374785        1.0     Z P
# 374786        2.0     Z P
# 374787        2.0     Z Z
# 374788        2.0     Z Z
# 374789        2.0     Z P
# 374790        2.0     Z Z
# 374791        2.0     Z T
# 374792        2.0     Z P
# 374793        2.0     T P
#
# [374794 rows x 15 columns]

# %%
sns.factorplot('addon_int', 'player_1_race_int', hue='player_1_match_status_int', data=data)

# %%
sns.barplot('matchup', hue='player_1_match_status', data=data)
